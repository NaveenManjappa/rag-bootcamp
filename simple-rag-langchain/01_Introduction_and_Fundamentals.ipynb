# %% [markdown]
# # 📚 Notebook 01: Introduction and Fundamentals
#
# **LangChain 1.0.5+ | Mixed Level Class**
#
# ---
#
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will understand:
# 1. What LangChain is and why it's useful
# 2. LangChain's modular architecture
# 3. Core concepts: Documents, Chains, and LCEL
# 4. How to set up your development environment
# 5. The difference between LangChain and traditional ML pipelines
#
# ---
#
# ## 📖 Table of Contents
#
# 1. [What is LangChain?](#what-is-langchain)
# 2. [LangChain Architecture](#architecture)
# 3. [Environment Setup](#setup)
# 4. [Core Concepts](#core-concepts)
# 5. [Quick Start Example](#quick-start)
# 6. [LangChain vs Traditional Pipelines](#comparison)
# 7. [Summary & Next Steps](#summary)
#
# ---

# %% [markdown]
# <a id="what-is-langchain"></a>
# ## 1. What is LangChain? 🤔
#
# ### 🔰 BEGINNER SECTION
#
# **LangChain** is an open-source framework that makes it easy to build applications powered by Large Language Models (LLMs) like GPT-4, Claude, or Llama.
#
# ### Why LangChain?
#
# Imagine you want to build a chatbot that can:
# - Answer questions about your company's PDF documents
# - Search through your database
# - Remember previous conversations
# - Call external APIs
#
# Without LangChain, you'd need to:
# 1. ✍️ Write code to load and parse PDFs
# 2. ✍️ Convert text to embeddings
# 3. ✍️ Store embeddings in a vector database
# 4. ✍️ Implement semantic search
# 5. ✍️ Format prompts for the LLM
# 6. ✍️ Handle LLM API calls
# 7. ✍️ Manage conversation memory
#
# **With LangChain:**
# - ✅ All these components are pre-built and ready to use
# - ✅ You just connect them like LEGO blocks
# - ✅ Focus on your application logic, not infrastructure
#
# ### 🎓 INTERMEDIATE NOTE
#
# LangChain provides:
# - **Abstractions**: Unified interfaces for different LLMs, vector stores, and tools
# - **Chains**: Composable workflows using LCEL (LangChain Expression Language)
# - **Agents**: Autonomous systems that can use tools and make decisions
# - **Memory**: Conversation history and context management
# - **Callbacks**: Monitoring, logging, and debugging hooks

# %% [markdown]
# <a id="architecture"></a>
# ## 2. LangChain Architecture 🏗️
#
# ### 🔰 BEGINNER: Visual Architecture
#
# ```
# ┌─────────────────────────────────────────────────────────┐
# │                    YOUR APPLICATION                     │
# └─────────────────────────────────────────────────────────┘
#                            ↓
# ┌─────────────────────────────────────────────────────────┐
# │                  LANGCHAIN FRAMEWORK                    │
# │  ┌──────────┐  ┌──────────┐  ┌──────────┐  ┌─────────┐  │
# │  │ Document │  │   Text   │  │ Embeddings│  │ Vector  │ │
# │  │ Loaders  │→ │ Splitters│→ │  Models   │→ │ Stores  │ │
# │  └──────────┘  └──────────┘  └──────────┘  └─────────┘│
# │                                                         │
# │  ┌──────────┐  ┌──────────┐  ┌──────────┐               │
# │  │Retrievers│  │ Prompts  │  │   LLMs   │               │
# │  └──────────┘  └──────────┘  └──────────┘               │
# │                                                         │
# │  ┌──────────────────────────────────────────────────┐   │
# │  │         LCEL (LangChain Expression Language)     │   │
# │  │         Connects everything with | operator      │   │
# │  └──────────────────────────────────────────────────┘   │
# └─────────────────────────────────────────────────────────┘
#                            ↓
# ┌─────────────────────────────────────────────────────────┐
# │             EXTERNAL SERVICES & DATA                    │
# │  • OpenAI/Anthropic APIs  • Vector Databases            │
# │  • PDF Files              • Websites                    │
# │  • Databases              • APIs                        │
# └─────────────────────────────────────────────────────────┘
# ```
#
# ### 🎓 INTERMEDIATE: Package Structure (LangChain 1.0+)
#
# LangChain is organized into several packages:
#
# | Package | Purpose | Example Imports |
# |---------|---------|------------------|
# | **langchain-core** | Core abstractions, base classes | `from langchain_core.documents import Document` |
# | **langchain-community** | Community integrations (loaders, vector stores) | `from langchain_community.document_loaders import PyPDFLoader` |
# | **langchain-openai** | OpenAI-specific integrations | `from langchain_openai import ChatOpenAI, OpenAIEmbeddings` |
# | **langchain-text-splitters** | Text splitting utilities | `from langchain_text_splitters import RecursiveCharacterTextSplitter` |
#
# **Why this matters:** In LangChain 1.0+, you import from specific packages instead of `langchain` directly. This reduces dependencies and improves modularity.

# %% [markdown]
# <a id="setup"></a>
# ## 3. Environment Setup 🛠️
#
# ### 🔰 BEGINNER: Step-by-Step Setup
#
# Let's verify your environment is ready!

# %%
# Step 1: Check Python version (should be 3.9+)
import sys
print(f"Python version: {sys.version}")

# Check if Python is 3.9 or higher
if sys.version_info >= (3, 9):
    print("✅ Python version is compatible")
else:
    print("❌ Please upgrade to Python 3.9 or higher")
# Out:
# Python version: 3.11.14 (main, Oct 14 2025, 21:21:22) [MSC v.1944 64 bit (AMD64)]
# ✅ Python version is compatible

# %%
# Step 2: Import LangChain and check version
import langchain
from langchain_core import __version__ as core_version

print(f"LangChain version: {langchain.__version__}")
print(f"LangChain Core version: {core_version}")

# We're using LangChain 1.0.5+ for this course
if langchain.__version__ >= "1.0":
    print("✅ LangChain 1.0+ detected")
else:
    print("❌ Please upgrade: pip install --upgrade langchain")
# Out:
# LangChain version: 1.0.5
# LangChain Core version: 1.0.5
# ✅ LangChain 1.0+ detected

# %%
# Step 3: Load environment variables (API keys)
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()

# Check if OpenAI API key is set
# NOTE: We don't print the actual key for security!
if os.getenv("OPENAI_API_KEY"):
    print("✅ OPENAI_API_KEY found")
else:
    print("❌ OPENAI_API_KEY not found")
    print("   Create a .env file with: OPENAI_API_KEY=your-key-here")

# Check for Google API key (optional, for Google Gemini)
if os.getenv("GOOGLE_API_KEY"):
    print("✅ GOOGLE_API_KEY found")
else:
    print("⚠️  GOOGLE_API_KEY not found (optional for this notebook)")
# Out:
# ✅ OPENAI_API_KEY found
# ✅ GOOGLE_API_KEY found

# %% [markdown]
# ### 📝 Setting Up Your .env File
#
# If you don't have a `.env` file, create one in the project root:
#
# ```bash
# # .env file
# OPENAI_API_KEY=sk-proj-your-key-here
# GOOGLE_API_KEY=your-google-key-here
# ```
#
# **⚠️ SECURITY WARNING:**
# - Never commit `.env` files to Git
# - Add `.env` to your `.gitignore` file
# - Never hardcode API keys in your code

# %% [markdown]
# <a id="core-concepts"></a>
# ## 4. Core Concepts 📚
#
# ### 4.1 Documents 📄
#
# ### 🔰 BEGINNER
#
# A **Document** is LangChain's way of representing a piece of text with metadata.
#
# Think of it like a note card:
# - **Front (page_content):** The actual text
# - **Back (metadata):** Information about the text (source, page number, date, etc.)

# %%
# Creating a Document manually
from langchain_core.documents import Document

# Create a simple document
doc = Document(
    page_content="LangChain makes building LLM applications easy!",
    metadata={
        "source": "introduction.txt",
        "author": "LangChain Team",
        "date": "2025-01-15"
    }
)

# Access the content
print("Content:")
print(doc.page_content)
print("\nMetadata:")
print(doc.metadata)
print(f"\nSource: {doc.metadata['source']}")
# Out:
# Content:
# LangChain makes building LLM applications easy!
#
# Metadata:
# {'source': 'introduction.txt', 'author': 'LangChain Team', 'date': '2025-01-15'}
#
# Source: introduction.txt

# %% [markdown]
# ### 🎓 INTERMEDIATE: Why Metadata Matters
#
# Metadata is crucial for:
# 1. **Citation**: Showing users where information came from
# 2. **Filtering**: Only search documents from specific sources
# 3. **Debugging**: Tracking which documents are being retrieved
# 4. **Analytics**: Understanding which sources are most useful

# %%
# Creating multiple documents (like a mini knowledge base)
documents = [
    Document(
        page_content="Python is a high-level programming language.",
        metadata={"category": "programming", "difficulty": "beginner"}
    ),
    Document(
        page_content="Machine learning is a subset of artificial intelligence.",
        metadata={"category": "AI", "difficulty": "intermediate"}
    ),
    Document(
        page_content="RAG combines retrieval and generation for better LLM outputs.",
        metadata={"category": "AI", "difficulty": "advanced"}
    )
]

# Print all documents
for i, doc in enumerate(documents, 1):
    print(f"\n📄 Document {i}:")
    print(f"   Content: {doc.page_content}")
    print(f"   Category: {doc.metadata['category']}")
    print(f"   Difficulty: {doc.metadata['difficulty']}")
# Out:
# 📄 Document 1:
#    Content: Python is a high-level programming language.
#    Category: programming
#    Difficulty: beginner
#
# 📄 Document 2:
#    Content: Machine learning is a subset of artificial intelligence.
#    Category: AI
#    Difficulty: intermediate
#
# 📄 Document 3:
#    Content: RAG combines retrieval and generation for better LLM outputs.
#    Category: AI
#    Difficulty: advanced

# %% [markdown]
# ### 4.2 LCEL (LangChain Expression Language) 🔗
#
# ### 🔰 BEGINNER
#
# **LCEL** is a way to connect different components using the pipe operator `|`.
#
# Think of it like a factory assembly line:
# ```
# Input → Component 1 → Component 2 → Component 3 → Output
# ```
#
# ### Before LCEL (Old Way - Messy!):
# ```python
# output = component3(component2(component1(input)))
# ```
#
# ### With LCEL (New Way - Clean!):
# ```python
# chain = component1 | component2 | component3
# output = chain.invoke(input)
# ```

# %% [markdown]
# ### 🎓 INTERMEDIATE: LCEL Deep Dive
#
# LCEL provides:
# - **Streaming**: Stream outputs as they're generated
# - **Batch Processing**: Process multiple inputs efficiently
# - **Async Support**: Non-blocking operations
# - **Debugging**: Better error messages and logging
# - **Type Safety**: Better IDE autocomplete
#
# **Key Methods:**
# - `.invoke(input)`: Process single input
# - `.batch([input1, input2])`: Process multiple inputs
# - `.stream(input)`: Stream output tokens
# - `.ainvoke(input)`: Async version of invoke

# %%
# Simple LCEL Example: String Transformation Chain
from langchain_core.runnables import RunnableLambda

# Create simple transformation functions
def uppercase(text: str) -> str:
    """Convert text to uppercase"""
    print(f"  Step 1: uppercase → {text.upper()}")
    return text.upper()

def add_prefix(text: str) -> str:
    """Add a prefix to text"""
    result = f"RESULT: {text}"
    print(f"  Step 2: add_prefix → {result}")
    return result

def add_emoji(text: str) -> str:
    """Add emoji to text"""
    result = f"✅ {text}"
    print(f"  Step 3: add_emoji → {result}")
    return result

# Create runnables (components that can be chained)
uppercase_runnable = RunnableLambda(uppercase)
prefix_runnable = RunnableLambda(add_prefix)
emoji_runnable = RunnableLambda(add_emoji)

# Build the chain using LCEL
chain = uppercase_runnable | prefix_runnable | emoji_runnable

# Execute the chain
print("Input: 'hello langchain'")
print("\nProcessing:")
result = chain.invoke("hello langchain")
print(f"\nFinal Output: {result}")
# Out:
# Input: 'hello langchain'
#
# Processing:
#   Step 1: uppercase → HELLO LANGCHAIN
#   Step 2: add_prefix → RESULT: HELLO LANGCHAIN
#   Step 3: add_emoji → ✅ RESULT: HELLO LANGCHAIN
#
# Final Output: ✅ RESULT: HELLO LANGCHAIN

# %% [markdown]
# ### 4.3 Chains 🔗
#
# ### 🔰 BEGINNER
#
# A **Chain** is a sequence of operations. Common chain types:
#
# 1. **Simple Chain**: Input → Process → Output
# 2. **RAG Chain**: Query → Retrieve → Generate → Answer
# 3. **Multi-step Chain**: Input → Step 1 → Step 2 → Step 3 → Output
#
# We'll build complex chains in later notebooks!

# %% [markdown]
# <a id="quick-start"></a>
# ## 5. Quick Start Example 🚀
#
# ### 🔰 BEGINNER: Your First LLM Call
#
# Let's make our first call to an LLM using LangChain!

# %%
# Import ChatOpenAI (the LLM interface)
from langchain_openai import ChatOpenAI

# Initialize the LLM
# model: Which GPT model to use
# temperature: 0 = deterministic, 1 = creative
llm = ChatOpenAI(
    model="gpt-5-nano",  # Cheaper, faster model for learning
    temperature=0  # Deterministic outputs for learning
)

# Make a simple call
response = llm.invoke("What is LangChain in one sentence?")

# Print the response
print("Question: What is LangChain in one sentence?")
print(f"\nAnswer: {response.content}")
# Out:
# Question: What is LangChain in one sentence?
#
# Answer: LangChain is an open-source framework that helps you build AI-powered applications by composing language models with prompts, chains, tools, memory, and agents.

# %% [markdown]
# ### 🎓 INTERMEDIATE: Understanding the Response Object

# %%
# The response is an AIMessage object with metadata
print("Response Type:", type(response))
print("\nContent:", response.content)
print("\nResponse Metadata:")
print(response.response_metadata)

# Access specific metadata
if 'token_usage' in response.response_metadata:
    usage = response.response_metadata['token_usage']
    print(f"\nTokens Used:")
    print(f"  Prompt: {usage.get('prompt_tokens', 'N/A')}")
    print(f"  Completion: {usage.get('completion_tokens', 'N/A')}")
    print(f"  Total: {usage.get('total_tokens', 'N/A')}")
# Out:
# Response Type: <class 'langchain_core.messages.ai.AIMessage'>
#
# Content: LangChain is an open-source framework that helps you build AI-powered applications by composing language models with prompts, chains, tools, memory, and agents.
#
# Response Metadata:
# {'token_usage': {'completion_tokens': 359, 'prompt_tokens': 14, 'total_tokens': 373, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CdjjZYJKVifxssd94xDSJMSIRGiFB', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}
#
# Tokens Used:
#   Prompt: 14
#   Completion: 359
#   Total: 373

# %% [markdown]
# ### 🔰 BEGINNER: Using Prompts
#
# Instead of plain strings, use **prompt templates** for better control:

# %%
from langchain_core.prompts import ChatPromptTemplate

# Create a prompt template
# {topic} is a variable we'll fill in later
prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple terms suitable for beginners."
)

# View the prompt structure
print("Prompt Template:")
print(prompt.messages[0].prompt.template)
# Out:
# Prompt Template:
# Explain {topic} in simple terms suitable for beginners.

# %%
# Build a chain: Prompt → LLM
from langchain_core.output_parsers import StrOutputParser

# Components:
# 1. prompt: Formats the input
# 2. llm: Generates the response
# 3. StrOutputParser: Extracts just the text from the response

chain = prompt | llm | StrOutputParser()

# Use the chain with different topics
topics = ["machine learning", "embeddings", "vector databases"]

for topic in topics:
    print(f"\n{'='*60}")
    print(f"Topic: {topic.upper()}")
    print('='*60)
    
    # Invoke the chain
    explanation = chain.invoke({"topic": topic})
    print(explanation)
# Out:
# ============================================================
# Topic: MACHINE LEARNING
# ============================================================
# Here's a beginner-friendly way to think about machine learning (ML).
#
# - The big idea
#   - ML is about teaching computers to make good guesses or decisions from examples, instead of giving them a giant set of fixed rules to follow.
#   - You show the computer lots of data, it learns patterns, and then it can make predictions on new data.
#
# - A simple story
#   - Imagine you’re teaching a child to tell cats from dogs. You show thousands of pictures and label them “cat” or “dog.” Over time, the child notices patterns (pointy ears, whiskers, shapes) and can guess correctly on new pictures. ML works the same way for computers: learn from examples and generalize to new cases.
#
# - Key terms (in plain language)
#   - Data: Examples you learn from (pictures, numbers, text, etc.).
#   - Features: The things about each example you look at (for a house: size, location, age).
#   - Label/target: The answer you want to predict (for a house: the price).
#   - Model: The computer’s rule or function that maps features to a prediction.
#   - Training: The process of adjusting the model so it fits the data well.
#   - Testing/validation: Checking how well the model does on new, unseen data.
#   - Prediction: The model’s guess for a new example.
#   - Generalization: How well the model works on data it hasn’t seen before.
#   - Overfitting: The model gets very good at the training data but fails on new data.
#   - Underfitting: The model is too simple and misses obvious patterns.
#
# - Types of learning (very high-level)
#   - Supervised learning: You train with labeled data (you know the answers). Example: predicting house prices from features.
#   - Unsupervised learning: No labels. The goal is to find patterns or groups in the data. Example: grouping customers by similar buying habits.
#   - Reinforcement learning: An agent learns by trying actions and getting rewards or punishments. Example: a game-playing AI learns by playing many rounds.
#
# - A simple workflow to build ML solutions
#   1) Collect data: Gather examples with features and the correct answer (labels).
#   2) Clean and prepare: Handle missing values, normalize numbers, maybe convert text into numbers.
#   3) Split the data: Put some data aside for testing (train vs. test).
#   4) Choose a model: Pick a simple method to start with.
#   5) Train the model: Let the computer find the best rules from the training data.
#   6) Evaluate: See how well it predicts the test data.
#   7) Improve: Try better features, more data, or a different model.
#   8) Deploy: Use the model to make real predictions on new data.
#
# - A concrete tiny example: predicting house prices
#   - Features: size (square feet), number of bedrooms, age of the house.
#   - Label: price.
#   - Process: collect many houses with these features and their prices, split into train and test, train a model to map (size, bedrooms, age) to price, test how close the predictions are to real prices on the test set, and then use the model to predict prices of new houses.
#
# - Common models at a very high level
#   - Linear models (e.g., linear regression): A straight-line or straight-slope rule that maps features to a number. Easy to understand and fast.
#   - Decision trees: A flow-chart like model that asks simple questions (is size > 1500?), splitting data step by step.
#   - Random forests / gradient boosting: Many trees combined to get better predictions.
#   - Neural networks: Small networks of connected nodes inspired by brains; good for complex patterns but harder to interpret.
#   - Clustering (unsupervised): Group similar items together (e.g., grouping customers by behavior) without using a “correct answer.”
#
# - Important ideas to keep in mind
#   - Generalization is the goal: You want good performance on new data, not just the data you saw.
#   - Data quality matters: Bad or biased data leads to bad predictions.
#   - Watch for overfitting: If a model is too tailored to the training data, it won’t predict well on new data.
#   - Features matter: The right features can make a simple model work very well; bad features can make a complex model fail.
#   - Ethics and fairness: Be mindful of biases in data that can affect predictions.
#
# - How to start learning
#   - Start with intuition and small projects: e.g., a simple dataset about houses or students, build a basic model, and see how changing features affects predictions.
#   - Learn by doing with beginner-friendly tools: Python with libraries like scikit-learn makes many ML ideas tangible.
#   - Explore introductory resources: beginner courses or tutorials that cover the concepts above with hands-on examples.
#
# If you want, tell me what you’re curious about (e.g., classifying emails, predicting prices, clustering customers), and I can tailor a simple, step-by-step beginner activity you can try.
#
# ============================================================
# Topic: EMBEDDINGS
# ============================================================
# Embeddings are a way to turn things like words or pictures into numbers so computers can reason about them. Here’s a beginner-friendly way to think about them.
#
# - Simple idea: An embedding is a map from items (like words) to points in a space made of numbers. Each item gets a vector (a list of numbers), not just a single label.
#
# - Why this helps: In this space, items that are alike sit near each other. Distant items are less related. Dense vectors (lots of numbers nonzero) are usually easier for computers to work with than sparse labels.
#
# - How it’s different from the old way: Old methods often used one-hot encoding, where each word is a long, sparse vector with a 1 in its own position and 0s elsewhere. Embeddings compress that information into a shorter, continuous vector where similar words end up close together.
#
# - How they’re learned (high level):
#   - You train on lots of data (like lots of text).
#   - The model adjusts the numbers in each word’s vector so that words that appear in similar contexts end up with similar vectors.
#   - There are famous methods like Word2Vec and GloVe. More advanced ones (contextual embeddings) make the vector depend on the sentence, not just the word in isolation.
#
# - Static vs contextual:
#   - Static embeddings: each word has one vector (e.g., “bank” always has the same vector). Works well for many tasks.
#   - Contextual embeddings: a word’s vector can change depending on the surrounding words (e.g., “bank” in “river bank” vs. “financial bank”). This is used in modern models like BERT.
#
# - What the vectors can do:
#   - Measure similarity: words that are alike have similar vectors (you can compare them with cosine similarity or distance).
#   - Featurize data: use the vector as input to a machine learning model (classification, recommendation, etc.).
#   - Visualize relationships: reduce dimensions and plot to see clusters of related items.
#   - Do word analogies (often shown with a “king – man + woman ≈ queen” idea) that illustrate how the space captures relationships.
#
# - A simple mental model:
#   - Imagine a map where each word is a city. Similar words lie near each other (cat, dog near each other; carrot far away). The distances reflect how closely they’re related in language use.
#
# - Quick, concrete example (toy idea):
#   - Suppose we plot words in 2D. “cat” might be at (0.8, 0.2), “dog” at (0.75, 0.25), and “carrot” at (-0.6, 0.9). Cat and dog are close; carrot is far away. If you swap “cat” with “feline,” you’d expect a nearby point as well.
#
# - Practical tips:
#   - Use pre-trained embeddings when possible (they’re trained on lots of data and work well out of the box).
#   - If you train your own, you’ll adjust the vectors as you train your task, so they become tailored to your data.
#   - Be mindful of biases in the data that embeddings can pick up.
#
# Glossary (quick):
# - Vector: a list of numbers representing an item.
# - Embedding: the mapping from items to vectors.
# - Dense vs sparse: dense means most numbers are used; sparse means many zeros (like one-hot).
# - Cosine similarity: a common way to measure how close two vectors are in direction.
# - Static vs contextual embeddings: whether the vector is the same for a word everywhere, or depends on context.
#
# If you’d like, I can give a tiny, concrete example with a few words and show how their vectors might look and how to check which words are “close.”
#
# ============================================================
# Topic: VECTOR DATABASES
# ============================================================
# Here’s a simple, beginner-friendly explanation of vector databases.
#
# What is a vector database?
# - A vector database is a specialized database that stores numbers called vectors (embeddings) instead of just text or rows.
# - Each object (a document, image, product, etc.) is turned into a vector using a machine learning model. This vector is like a numeric fingerprint that captures its meaning or content.
#
# Why use them?
# - Regular keyword search looks for exact words. A vector search looks for semantic similarity—items that are alike in meaning, even if they don’t share the same words.
# - For example, a query like “best science fiction about AI” can retrieve books whose descriptions are talking about AI, even if the exact words aren’t the same.
#
# How do they work at a high level?
# - Convert: You convert each item into a vector using an embedding model (text, images, audio, etc.).
# - Store: You save these vectors in the vector database, often with extra information (metadata) like category, price, date.
# - Query: You convert your search query into a vector and ask the database to find the closest stored vectors (the most similar items).
# - Return: The database returns the best matches, usually with their metadata and sometimes a score showing how close they are.
#
# Key differences from a traditional database
# - Focus: Traditional databases store rows and columns and search by exact matches or simple filters. Vector databases focus on measuring similarity between high-dimensional vectors.
# - Semantics: They’re designed to find items that are semantically similar, not just text that matches keywords.
# - Hybrid search: Many support combining vector similarity with standard filters (e.g., keep only items in a certain category or price range).
#
# Important terms, in plain language
# - Vector / embedding: A list of numbers that encodes the meaning or content of something.
# - Distance / similarity: How close two vectors are; common measures include cosine similarity and Euclidean distance.
# - Nearest neighbors: The most similar vectors to your query vector.
# - Approximate nearest neighbors (ANN): A fast, approximate way to find close vectors when you have lots of data. Usually faster than exact search.
# - Metadata: Extra information attached to each vector (like category, author, date). Used for filtering.
#
# Common uses
# - Semantic search for documents or knowledge bases.
# - Recommending products or content that are similar to what a user likes.
# - Finding visually similar images or near-duplicate media.
# - Matching audio or video segments by content rather than exact keywords.
# - Fraud detection and anomaly spotting by measuring how new items differ from past ones.
#
# Simple, concrete example
# - You have a movie site. For every movie, you generate a vector from its plot description.
# - You store these vectors along with title, genre, year, etc.
# - A user types: “sci-fi movies about artificial intelligence.”
# - You convert that query into a vector, ask the vector database for the nearest movie vectors, and return the top matches. The results feel semantically right even if the exact words aren’t in the movie descriptions.
#
# How to get started (very high level)
# - Pick a tool: popular options include Pinecone, Milvus, Weaviate, Vespa, Qdrant, etc.
# - Create embeddings: use a model to turn text (or images, etc.) into vectors.
# - Insert: store the vectors in the database with any helpful metadata.
# - Search: convert your query into a vector and retrieve the closest stored vectors.
# - Optionally filter: apply metadata filters on top of the vector results to refine the list.
#
# Pros and cons
# - Pros: great for semantic search and recommendations; scalable; supports hybrid search (vectors plus metadata); often faster for large datasets.
# - Cons: requires embedding models and some setup; embeddings can drift as models update; costs can add up with large datasets.
#
# In short
# A vector database is a smart place to store numerical representations of things and quickly find items that are semantically similar, even if they don’t share exact words. It’s especially helpful for search and recommendations that rely on meaning rather than exact text.

# %% [markdown]
# ### 🎓 INTERMEDIATE: Batch Processing
#
# Process multiple inputs efficiently using `.batch()`:

# %%
# Batch process multiple topics at once
topics_batch = [
    {"topic": "RAG"},
    {"topic": "LCEL"},
    {"topic": "LangChain agents"}
]

# Batch processing is more efficient than calling invoke() multiple times
results = chain.batch(topics_batch)

# Print results
for i, (input_dict, result) in enumerate(zip(topics_batch, results), 1):
    print(f"\n{i}. {input_dict['topic'].upper()}:")
    print(f"   {result[:100]}...")  # Print first 100 chars
# Out:
# 1. RAG:
#    RAG stands for Retrieval-Augmented Generation.
#
# In simple terms:
# - It’s a way for an AI to answer qu...
#
# 2. LCEL:
#    I’m not sure which LCEL you mean—the acronym can stand for different things in different fields. Cou...
#
# 3. LANGCHAIN AGENTS:
#    Here’s a simple, beginner-friendly way to think about LangChain agents.
#
# What is a LangChain agent?
# ...

# %% [markdown]
# <a id="comparison"></a>
# ## 6. LangChain vs Traditional ML Pipelines 🆚
#
# ### 🔰 BEGINNER: Key Differences
#
# | Aspect | Traditional ML | LangChain |
# |--------|---------------|------------|
# | **Setup** | Complex, manual | Pre-built components |
# | **Integration** | Write custom code | Use existing integrations |
# | **Composability** | Difficult to chain | Easy with LCEL |
# | **Debugging** | Manual logging | Built-in callbacks |
# | **Prototyping** | Slow | Very fast |
# | **Code Reuse** | Limited | High |
#
# ### Example: Building a Q&A System
#
# #### Without LangChain (50+ lines):
# ```python
# import openai
# import PyPDF2
# import faiss
# import numpy as np
#
# # 1. Load PDF manually
# def load_pdf(file_path):
#     reader = PyPDF2.PdfReader(file_path)
#     text = ""
#     for page in reader.pages:
#         text += page.extract_text()
#     return text
#
# # 2. Split text manually
# def split_text(text, chunk_size=1000):
#     chunks = []
#     for i in range(0, len(text), chunk_size):
#         chunks.append(text[i:i+chunk_size])
#     return chunks
#
# # 3. Create embeddings manually
# def create_embeddings(chunks):
#     embeddings = []
#     for chunk in chunks:
#         response = openai.Embedding.create(
#             input=chunk,
#             model="text-embedding-ada-002"
#         )
#         embeddings.append(response['data'][0]['embedding'])
#     return np.array(embeddings)
#
# # 4. Create vector store manually
# def create_vector_store(embeddings):
#     dimension = embeddings.shape[1]
#     index = faiss.IndexFlatL2(dimension)
#     index.add(embeddings)
#     return index
#
# # 5. Search manually
# def search(query, index, chunks):
#     query_embedding = openai.Embedding.create(
#         input=query,
#         model="text-embedding-ada-002"
#     )['data'][0]['embedding']
#
#     distances, indices = index.search(
#         np.array([query_embedding]), k=3
#     )
#     return [chunks[i] for i in indices[0]]
#
# # 6. Generate answer manually
# def generate_answer(query, context):
#     prompt = f"Context: {context}\n\nQuestion: {query}\n\nAnswer:"
#     response = openai.ChatCompletion.create(
#         model="gpt-3.5-turbo",
#         messages=[{"role": "user", "content": prompt}]
#     )
#     return response['choices'][0]['message']['content']
#
# # Use it:
# text = load_pdf("document.pdf")
# chunks = split_text(text)
# embeddings = create_embeddings(chunks)
# index = create_vector_store(embeddings)
# relevant_chunks = search("What is RAG?", index, chunks)
# answer = generate_answer("What is RAG?", " ".join(relevant_chunks))
# ```
#
# #### With LangChain (10 lines!):
# ```python
# from langchain_community.document_loaders import PyPDFLoader
# from langchain_text_splitters import RecursiveCharacterTextSplitter
# from langchain_openai import OpenAIEmbeddings, ChatOpenAI
# from langchain_community.vectorstores import FAISS
# from langchain_core.prompts import ChatPromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from langchain_core.runnables import RunnablePassthrough
#
# # Load, split, embed, and store
# docs = PyPDFLoader("document.pdf").load()
# chunks = RecursiveCharacterTextSplitter(chunk_size=1000).split_documents(docs)
# vectorstore = FAISS.from_documents(chunks, OpenAIEmbeddings())
# retriever = vectorstore.as_retriever()
#
# # Build RAG chain
# prompt = ChatPromptTemplate.from_template(
#     "Context: {context}\n\nQuestion: {question}\n\nAnswer:"
# )
# chain = (
#     {"context": retriever, "question": RunnablePassthrough()}
#     | prompt | ChatOpenAI() | StrOutputParser()
# )
#
# # Use it:
# answer = chain.invoke("What is RAG?")
# ```
#
# **50+ lines → 10 lines!** 🎉

# %% [markdown]
# <a id="summary"></a>
# ## 7. Summary & Next Steps 📝
#
# ### 🎉 What You Learned
#
# ✅ **LangChain** is a framework that simplifies building LLM applications
#
# ✅ **Architecture** is modular: loaders, splitters, embeddings, vector stores, chains
#
# ✅ **Documents** contain `page_content` (text) and `metadata` (information about the text)
#
# ✅ **LCEL** uses the `|` operator to chain components together
#
# ✅ **Chains** connect multiple components to create complex workflows
#
# ✅ LangChain **dramatically reduces code** compared to manual implementations
#
# ### 🔰 For Beginners
# You now understand:
# - What LangChain is and why it's useful
# - How to set up your environment
# - Basic concepts: Documents and Chains
# - How to make your first LLM call
#
# ### 🎓 For Intermediate Learners
# You now understand:
# - LangChain's package structure (1.0+ reorganization)
# - LCEL internals and advantages
# - Metadata usage for filtering and citation
# - Batch processing for efficiency
#
# ### 📚 Next Notebooks
#
# 1. **Notebook 02**: Document Loaders (PDF, CSV, JSON, HTML)
# 2. **Notebook 03**: Text Splitting Strategies
# 3. **Notebook 04**: Embeddings and Vector Representations
# 4. **Notebook 05**: Vector Stores (FAISS, Chroma)
# 5. **Notebook 06**: Retrieval Strategies
# 6. **Notebook 07**: Complete RAG Pipeline
#
# ### 💡 Practice Exercises
#
# Before moving to the next notebook, try these:
#
# 1. **Easy**: Create 5 Documents about different topics with meaningful metadata
# 2. **Medium**: Build a chain that takes a topic and generates a haiku about it
# 3. **Advanced**: Create a chain that summarizes text in different styles (formal, casual, technical)
#
# ---
#
# ## 🎓 Additional Resources
#
# - [Official LangChain Documentation](https://python.langchain.com/docs/)
# - [LCEL Guide](https://python.langchain.com/docs/expression_language/)
# - [LangChain GitHub](https://github.com/langchain-ai/langchain)
#
# ---
#
# **Ready for more? Continue to Notebook 02: Document Loaders! 🚀**
